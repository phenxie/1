# %% [markdown]
# <a href="https://colab.research.google.com/github/phenxie/1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# !git clone https://github.com/llm-factory/FinancialData-SecondQuarter-2024.git
# Out:
# sample_data
# Cloning into 'FinancialData-SecondQuarter-2024'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 20.77 KiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls
# !node -v
# Out:
# FinancialData-SecondQuarter-2024  sample_data
# v20.19.0

# %%
# !git clone https://github.com/ConardLi/easy-dataset.git
# Out:
# Cloning into 'easy-dataset'...
# remote: Enumerating objects: 6755, done.
# remote: Counting objects: 100% (2156/2156), done.
# remote: Compressing objects: 100% (476/476), done.
# remote: Total 6755 (delta 1807), reused 1735 (delta 1635), pack-reused 4599 (from 1)
# Receiving objects: 100% (6755/6755), 16.70 MiB | 30.87 MiB/s, done.
# Resolving deltas: 100% (3777/3777), done.

# %%
# !cd easy-dataset && npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴npm warn deprecated npmlog@5.0.1: This package is no longer supported.
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴npm warn deprecated lodash.isequal@4.5.0: This package is deprecated. Use require('node:util').isDeepStrictEqual instead.
# ⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦npm warn deprecated node-domexception@1.0.0: Use your platform's native DOMException instead
# ⠦npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏npm warn deprecated gauge@3.0.2: This package is no longer supported.
# ⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹npm warn deprecated are-we-there-yet@2.0.0: This package is no longer supported.
# ⠹⠸⠼⠴⠦npm warn deprecated boolean@3.2.0: Package no longer supported. Contact Support at https://www.npmjs.com/support for more info.
# ...

# %%
# !npm run build && npm run start
# Out:
# npm error code ENOENT
# npm error syscall open
# npm error path /content/package.json
# npm error errno -2
# npm error enoent Could not read package.json: Error: ENOENT: no such file or directory, open '/content/package.json'
# npm error enoent This is related to npm not being able to find a file.
# npm error enoent
# npm error A complete log of this run can be found in: /root/.npm/_logs/2025-06-13T06_49_07_332Z-debug-0.log

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落
